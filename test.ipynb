# %%
prtint("筋トレ始めます")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-296e7d4cd60d> in <module>
# ----> 1 prtint("筋トレ始めます")
#
# NameError: name 'prtint' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0.3*np.pi, 500)
plt.plot(x, np.sin(x**2))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))

# %%
F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx$$
# Out:
#   File "<ipython-input-4-399ea5f15049>", line 1
#     F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx$$
#                ^
# SyntaxError: invalid character in identifier

# %%
F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx$$
# Out:
#   File "<ipython-input-5-9753760ea614>", line 1
#     F(k) = int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
#                ^
# SyntaxError: invalid syntax

# %%
F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
# Out:
#   File "<ipython-input-6-d59dc652854d>", line 1
#     F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
#                                                          ^
# SyntaxError: unexpected character after line continuation character

# %%
$$F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx$$
# Out:
#   File "<ipython-input-7-8e6be436e024>", line 1
#     $$F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx$$
#     ^
# SyntaxError: invalid syntax

# %%
F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx
# Out:
#   File "<ipython-input-8-d982ef717a52>", line 1
#     F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx
#                ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# F(k) = ¥int_{-¥infty}^{¥infty} f(x) e^{2¥pi i k} dx

# %%
$$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
# Out:
#   File "<ipython-input-9-8763a2399bf6>", line 1
#     $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %% [markdown]
# F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx

# %% [markdown]
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$
